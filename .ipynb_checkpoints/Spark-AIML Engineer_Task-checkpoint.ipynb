# %%
# Crop / Vegetation Classification using Sentinel-2 and Google Earth Engine

# Author: <Write your name>

# Area: <Write selected area name>

# Classes: Dense vegetation, sparse vegetation, non-vegetation


 

# !pip install earthengine-api geemap -q


 

import ee

import geemap

import pandas as pd

import matplotlib.pyplot as plt


 

# Authenticate and initialize Earth Engine

ee.Authenticate()

ee.Initialize(project='gen-lang-client-0869531784')


 

# ----------------------------------------------------

# 1. Define Area of Interest

# Change these coordinates to your selected agriculture area

# Example: small area near Bhubaneswar / Odisha

# ----------------------------------------------------


 

aoi = ee.Geometry.Rectangle([85.75, 20.20, 85.90, 20.35])


 

Map = geemap.Map(center=[20.275, 85.825], zoom=12)

Map.addLayer(aoi, {}, "Area of Interest")

Map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# [notice] A new release of pip is available: 25.3 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Map(center=[20.275, 85.825], controls=(WidgetControl(options=['position', 'transparent_bg'], position='toprigh…

# %%
# ----------------------------------------------------

# 2. Load Sentinel-2 Surface Reflectance Data

# ----------------------------------------------------


 

start_date = "2024-11-01"

end_date = "2025-02-28"


 

s2 = (

    ee.ImageCollection("COPERNICUS/S2_SR_HARMONIZED")

    .filterBounds(aoi)

    .filterDate(start_date, end_date)

    .filter(ee.Filter.lt("CLOUDY_PIXEL_PERCENTAGE", 20))

)


 

image = s2.median().clip(aoi)


 

# Select useful bands

bands = ["B2", "B3", "B4", "B8", "B11", "B12"]


 

# ----------------------------------------------------

# 3. Compute NDVI

# NDVI = (NIR - Red) / (NIR + Red)

# Sentinel-2: NIR = B8, Red = B4

# ----------------------------------------------------


 

ndvi = image.normalizedDifference(["B8", "B4"]).rename("NDVI")

image_with_ndvi = image.select(bands).addBands(ndvi)


 

# Visualization

rgb_vis = {

    "bands": ["B4", "B3", "B2"],

    "min": 0,

    "max": 3000

}


 

ndvi_vis = {

    "min": -0.2,

    "max": 0.8,

    "palette": ["brown", "yellow", "green"]

}


 

Map = geemap.Map(center=[20.275, 85.825], zoom=12)

Map.addLayer(image, rgb_vis, "Sentinel-2 RGB")

Map.addLayer(ndvi, ndvi_vis, "NDVI")

Map.addLayer(aoi, {}, "AOI")

Map

# %%
# ----------------------------------------------------

# 4. Create Manual Training Samples

# IMPORTANT:

# These are example polygons only.

# You must adjust them after visually checking the satellite image.

# ----------------------------------------------------


 

# Class 0: Non-vegetation / bare soil / built-up

non_veg = ee.FeatureCollection([

    ee.Feature(

        ee.Geometry.Polygon([[

            [85.780, 20.250],

            [85.785, 20.250],

            [85.785, 20.255],

            [85.780, 20.255],

            [85.780, 20.250]

        ]]),

        {"class": 0}

    )

])


 

# Class 1: Sparse vegetation

sparse_veg = ee.FeatureCollection([

    ee.Feature(

        ee.Geometry.Polygon([[

            [85.810, 20.270],

            [85.815, 20.270],

            [85.815, 20.275],

            [85.810, 20.275],

            [85.810, 20.270]

        ]]),

        {"class": 1}

    )

])


 

# Class 2: Dense vegetation / crop

dense_veg = ee.FeatureCollection([

    ee.Feature(

        ee.Geometry.Polygon([[

            [85.840, 20.300],

            [85.845, 20.300],

            [85.845, 20.305],

            [85.840, 20.305],

            [85.840, 20.300]

        ]]),

        {"class": 2}

    )

])


 

training_polygons = non_veg.merge(sparse_veg).merge(dense_veg)


 

Map = geemap.Map(center=[20.275, 85.825], zoom=12)

Map.addLayer(image, rgb_vis, "Sentinel-2 RGB")

Map.addLayer(training_polygons, {}, "Training Samples")

Map

# %%
# ----------------------------------------------------

# 5. Sample Pixels from Training Polygons

# ----------------------------------------------------


 

input_bands = bands + ["NDVI"]


 

samples = image_with_ndvi.select(input_bands).sampleRegions(

    collection=training_polygons,

    properties=["class"],

    scale=10

)


 

# Random split: 70% training, 30% testing

samples = samples.randomColumn("random")

train_samples = samples.filter(ee.Filter.lt("random", 0.7))

test_samples = samples.filter(ee.Filter.gte("random", 0.7))


 

print("Training samples:", train_samples.size().getInfo())

print("Testing samples:", test_samples.size().getInfo())

# %%
# ----------------------------------------------------

# 6. Train Random Forest Classifier

# ----------------------------------------------------


 

classifier = ee.Classifier.smileRandomForest(numberOfTrees=50).train(

    features=train_samples,

    classProperty="class",

    inputProperties=input_bands

)


 

classified = image_with_ndvi.select(input_bands).classify(classifier)


 

class_vis = {

    "min": 0,

    "max": 2,

    "palette": ["gray", "yellow", "green"]

}


 

Map = geemap.Map(center=[20.275, 85.825], zoom=12)

Map.addLayer(image, rgb_vis, "Sentinel-2 RGB")

Map.addLayer(ndvi, ndvi_vis, "NDVI")

Map.addLayer(classified, class_vis, "Classification Map")

Map.addLayer(aoi, {}, "AOI")

Map

# %%
# ----------------------------------------------------

# 7. Accuracy Assessment

# ----------------------------------------------------


 

validated = test_samples.classify(classifier)


 

confusion_matrix = validated.errorMatrix("class", "classification")


 

print("Confusion Matrix:")

print(confusion_matrix.getInfo())


 

print("Overall Accuracy:")

print(confusion_matrix.accuracy().getInfo())


 

print("Kappa:")

print(confusion_matrix.kappa().getInfo())

# %%
# ----------------------------------------------------

# 8. Export Output Maps to Google Drive

# ----------------------------------------------------


 

task1 = ee.batch.Export.image.toDrive(

    image=ndvi,

    description="NDVI_Map",

    folder="Crop_Classification_Output",

    fileNamePrefix="ndvi_map",

    region=aoi,

    scale=10,

    maxPixels=1e13

)


 

task2 = ee.batch.Export.image.toDrive(

    image=classified,

    description="Classification_Map",

    folder="Crop_Classification_Output",

    fileNamePrefix="classification_map",

    region=aoi,

    scale=10,

    maxPixels=1e13

)


 

task1.start()

task2.start()


 

print("Export started. Check Google Drive after completion.")
